# %% [markdown]
# # Project 1: Digital Divide
#
# #### Based on PPIC's Just the Facts report ["California's Digital Divide"](https://www.ppic.org/publication/californias-digital-divide/)

# %% [markdown]
# ## Research Question(s):
# 1. What share households have access to high-speed internet?
# 2. Does this number vary across demographic groups? (in this case race/ethnicity).

# %% [markdown]
# ## Goal:
# * explore datafiles (`acsdata.data.gz`) and create a _working dataset_ from it.

# %% [markdown]
# ## Context:
# Obtained American Community Survey (ACS) survey data from [IPUMS](https://usa.ipums.org/usa/). <br>
# It contains basic demographics:
#   - age
#   - gender
#   - race/ethnicity
#
# and geographic indicators:
#   - state
#   - county

# %% [markdown]
# ***

# %% [markdown]
# **Step 1: Set up your working environment.**
#
# Import all necessary libraries and create `Path`s to your data directories. This ensures reproducibility across file systems (windows uses `\` instead of `/`)

# %%
# setting up working environment
import pandas as pd
from pathlib import Path
from datetime import datetime as dt
today = dt.today().strftime("%d-%b-%y")

print(today)
# Out:
# 29-Apr-19

# %%
# data folder and paths
RAW_DATA_FOLDER = Path("../data/raw/")
INTERIM_DATA_FOLDER = Path("../data/interim/")
PROCESSED_DATA_FOLDER = Path("../data/processed/")
FINAL_DATA_FOLDER = Path("../data/final/")

# %%
from tools import tree
import gzip

# %%
tree(RAW_DATA_FOLDER)
# Out:
# + ..\data\raw
#     + acs_data.dta.gz
#     + county_shapes.zip
#     + cps_data.dta.gz
#     + usa_00052.csv.gz
#     + usa_00053.dta.gz

# %%
# loading data and exploratory analysis
with gzip.open(RAW_DATA_FOLDER / 'usa_00053.dta.gz') as datafile:
    data = pd.read_stata(datafile)

# %%
data.shape
# Out:
# (3190040, 18)

# %%
data.describe()
# Out:
#              serial          hhwt     countyfip        pernum         perwt
# count  3.190040e+06  3.190040e+06  3.190040e+06  3.190040e+06  3.190040e+06
# mean   6.918400e+05  9.614892e+01  5.099185e+01  2.083905e+00  1.021050e+02
# std    4.064117e+05  7.594648e+01  8.809394e+01  1.340533e+00  8.314945e+01
# min    1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00
# 25%    3.350008e+05  5.100000e+01  0.000000e+00  1.000000e+00  5.300000e+01
# 50%    6.925320e+05  7.600000e+01  1.900000e+01  2.000000e+00  8.000000e+01
# 75%    1.047493e+06  1.170000e+02  7.300000e+01  3.000000e+00  1.240000e+02
# max    1.394399e+06  2.401000e+03  8.100000e+02  2.000000e+01  2.401000e+03

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3190040 entries, 0 to 3190039
# Data columns (total 18 columns):
# year         category
# serial       int32
# hhwt         int16
# statefip     category
# countyfip    int16
# gq           category
# cinethh      category
# cihispeed    category
# pernum       int8
# perwt        int16
# relate       category
# related      category
# sex          category
# age          category
# race         category
# raced        category
# hispan       category
# hispand      category
# dtypes: category(13), int16(3), int32(1), int8(1)
# memory usage: 100.4 MB

# %%
data.head()
# Out:
#    year  serial  hhwt statefip  countyfip                                gq  \
# 0  2017       1   206  alabama          0  households under 1970 definition
# 1  2017       2    45  alabama          0  households under 1970 definition
# 2  2017       3   136  alabama          0  households under 1970 definition
# 3  2017       3   136  alabama          0  households under 1970 definition
# 4  2017       3   136  alabama          0  households under 1970 definition
#
#                                              cinethh cihispeed  pernum  perwt  \
# 0  no internet access at this house, apartment, o...  n/a (gq)       1    206
# 1    yes, with a subscription to an internet service        no       1     45
# 2    yes, with a subscription to an internet service        no       1    136
# 3    yes, with a subscription to an internet service        no       2    121
# 4    yes, with a subscription to an internet service        no       3    111
#
#              relate           related     sex age  \
# 0  head/householder  head/householder    male  73
# 1  head/householder  head/householder  female  31
# 2  head/householder  head/householder    male  41
# 3            spouse            spouse  female  48
# 4             child             child    male  16
#
#                            race                         raced        hispan  \
# 0  black/african american/negro  black/african american/negro  not hispanic
# 1                         white                         white  not hispanic
# 2                         white                         white       mexican
# 3                         white                         white  not hispanic
# 4                         white                         white       mexican
#
#         hispand
# 0  not hispanic
# 1  not hispanic
# 2       mexican
# 3  not hispanic
# 4       mexican

# %% [markdown]
# Subset california
# ```python
# state_data = data[data['statefip'] == 'california'].copy()
# ```
# or
# ```python
# mask_state = data['statefip'] == 'california'
# state_data = data[mask_state].copy()
# ```
# or
# ```python
# california_mask = data['statefip'] == 'california'
# state_data = data.loc[mask_state, :].copy()
# ```

# %%
# subset california
mask_state = data['statefip'] == 'california'
state_data = data.loc[mask_state, ].copy()

# %%
state_data.head()
# Out:
#         year  serial  hhwt    statefip  countyfip  \
# 153275  2017   68211    59  california         67
# 153276  2017   68211    59  california         67
# 153277  2017   68211    59  california         67
# 153278  2017   68212    74  california          1
# 153279  2017   68212    74  california          1
#
#                                       gq  \
# 153275  households under 1970 definition
# 153276  households under 1970 definition
# 153277  households under 1970 definition
# 153278  households under 1970 definition
# 153279  households under 1970 definition
#
#                                                 cinethh  \
# 153275  yes, with a subscription to an internet service
# 153276  yes, with a subscription to an internet service
# 153277  yes, with a subscription to an internet service
# 153278  yes, with a subscription to an internet service
# 153279  yes, with a subscription to an internet service
#
#                                             cihispeed  pernum  perwt  \
# 153275  yes (cable modem, fiber optic or dsl service)       1     59
# 153276  yes (cable modem, fiber optic or dsl service)       2     57
# 153277  yes (cable modem, fiber optic or dsl service)       3     54
# 153278  yes (cable modem, fiber optic or dsl service)       1     75
# 153279  yes (cable modem, fiber optic or dsl service)       2     71
#
#                   relate           related     sex age             race  \
# 153275  head/householder  head/householder    male  45  two major races
# 153276            spouse            spouse  female  39  two major races
# 153277             child             child    male  15  two major races
# 153278  head/householder  head/householder    male  34          chinese
# 153279            spouse            spouse  female  33          chinese
#
#                                 raced        hispan       hispand
# 153275  white and other asian race(s)  not hispanic  not hispanic
# 153276  white and other asian race(s)  not hispanic  not hispanic
# 153277  white and other asian race(s)  not hispanic  not hispanic
# 153278                        chinese  not hispanic  not hispanic
# 153279                        chinese  not hispanic  not hispanic

# %%
# analysis 1 - trim your data set
## drop unnecessary variables OR select necessary variables and create another subset
state_data.drop(columns = ['gq', 'related', 'raced', 'hispand',])
# Out:
#         year  serial  hhwt    stateicp  countyfip  \
# 153275  2017   68211    59  california         67
# 153276  2017   68211    59  california         67
# 153277  2017   68211    59  california         67
# 153278  2017   68212    74  california          1
# 153279  2017   68212    74  california          1
# 153280  2017   68212    74  california          1
# 153281  2017   68212    74  california          1
# 153282  2017   68213    63  california         19
# 153283  2017   68214    75  california         67
# 153284  2017   68214    75  california         67
# 153285  2017   68214    75  california         67
# 153286  2017   68215    25  california        107
# 153287  2017   68215    25  california        107
# 153288  2017   68216    94  california         37
# 153289  2017   68216    94  california         37
# 153290  2017   68217    31  california         29
# 153291  2017   68217    31  california         29
# 153292  2017   68217    31  california         29
# 153293  2017   68217    31  california         29
# 153294  2017   68218   103  california         55
# 153295  2017   68218   103  california         55
# 153296  2017   68218   103  california         55
# 153297  2017   68219   107  california         47
# 153298  2017   68220   105  california         67
# 153299  2017   68220   105  california         67
# 153300  2017   68221    76  california          1
# 153301  2017   68222    50  california          1
# 153302  2017   68222    50  california          1
# 153303  2017   68223    65  california         97
# 153304  2017   68223    65  california         97
# ...      ...     ...   ...         ...        ...
# 530820  2017  217601    72  california         83
# 530821  2017  217602    40  california         75
# 530822  2017  217603   129  california         37
# 530823  2017  217604    17  california         73
# 530824  2017  217605   156  california         77
# 530825  2017  217606   149  california         37
# 530826  2017  217607    10  california         67
# 530827  2017  217608   114  california         37
# 530828  2017  217609    61  california         77
# 530829  2017  217610    28  california         59
# 530830  2017  217611    29  california         77
# 530831  2017  217612    17  california         67
# 530832  2017  217613    73  california         29
# 530833  2017  217614    22  california          1
# 530834  2017  217615   121  california         87
# 530835  2017  217616    19  california         65
# 530836  2017  217617    71  california         77
# 530837  2017  217618    50  california         37
# 530838  2017  217619    79  california         37
# 530839  2017  217620    21  california         37
# 530840  2017  217621    84  california         83
# 530841  2017  217622    12  california         71
# 530842  2017  217623    81  california         37
# 530843  2017  217624    33  california         71
# 530844  2017  217625    93  california         29
# 530845  2017  217626    25  california         67
# 530846  2017  217627    28  california         29
# 530847  2017  217628    41  california         39
# 530848  2017  217629    27  california         25
# 530849  2017  217630     6  california         29
#
#                                                   cinethh  \
# 153275    yes, with a subscription to an internet service
# 153276    yes, with a subscription to an internet service
# 153277    yes, with a subscription to an internet service
# 153278    yes, with a subscription to an internet service
# 153279    yes, with a subscription to an internet service
# 153280    yes, with a subscription to an internet service
# 153281    yes, with a subscription to an internet service
# 153282    yes, with a subscription to an internet service
# 153283    yes, with a subscription to an internet service
# 153284    yes, with a subscription to an internet service
# 153285    yes, with a subscription to an internet service
# 153286    yes, with a subscription to an internet service
# 153287    yes, with a subscription to an internet service
# 153288    yes, with a subscription to an internet service
# 153289    yes, with a subscription to an internet service
# 153290    yes, with a subscription to an internet service
# 153291    yes, with a subscription to an internet service
# 153292    yes, with a subscription to an internet service
# 153293    yes, with a subscription to an internet service
# 153294    yes, with a subscription to an internet service
# 153295    yes, with a subscription to an internet service
# 153296    yes, with a subscription to an internet service
# 153297    yes, with a subscription to an internet service
# 153298    yes, with a subscription to an internet service
# 153299    yes, with a subscription to an internet service
# 153300  no internet access at this house, apartment, o...
# 153301    yes, with a subscription to an internet service
# 153302    yes, with a subscription to an internet service
# 153303    yes, with a subscription to an internet service
# 153304    yes, with a subscription to an internet service
# ...                                                   ...
# 530820                                           n/a (gq)
# 530821                                           n/a (gq)
# 530822                                           n/a (gq)
# 530823                                           n/a (gq)
# 530824                                           n/a (gq)
# 530825                                           n/a (gq)
# 530826                                           n/a (gq)
# 530827                                           n/a (gq)
# 530828                                           n/a (gq)
# 530829                                           n/a (gq)
# 530830                                           n/a (gq)
# 530831                                           n/a (gq)
# 530832                                           n/a (gq)
# 530833                                           n/a (gq)
# 530834                                           n/a (gq)
# 530835                                           n/a (gq)
# 530836                                           n/a (gq)
# 530837                                           n/a (gq)
# 530838                                           n/a (gq)
# 530839                                           n/a (gq)
# 530840                                           n/a (gq)
# 530841                                           n/a (gq)
# 530842                                           n/a (gq)
# 530843                                           n/a (gq)
# 530844                                           n/a (gq)
# 530845                                           n/a (gq)
# 530846                                           n/a (gq)
# 530847                                           n/a (gq)
# 530848                                           n/a (gq)
# 530849                                           n/a (gq)
#
#                                             cihispeed  pernum  perwt  \
# 153275  yes (cable modem, fiber optic or dsl service)       1     59
# 153276  yes (cable modem, fiber optic or dsl service)       2     57
# 153277  yes (cable modem, fiber optic or dsl service)       3     54
# 153278  yes (cable modem, fiber optic or dsl service)       1     75
# 153279  yes (cable modem, fiber optic or dsl service)       2     71
# 153280  yes (cable modem, fiber optic or dsl service)       3     75
# 153281  yes (cable modem, fiber optic or dsl service)       4     75
# 153282  yes (cable modem, fiber optic or dsl service)       1     63
# 153283  yes (cable modem, fiber optic or dsl service)       1     74
# 153284  yes (cable modem, fiber optic or dsl service)       2     78
# 153285  yes (cable modem, fiber optic or dsl service)       3    122
# 153286  yes (cable modem, fiber optic or dsl service)       1     25
# 153287  yes (cable modem, fiber optic or dsl service)       2     35
# 153288  yes (cable modem, fiber optic or dsl service)       1     94
# 153289  yes (cable modem, fiber optic or dsl service)       2    123
# 153290                                             no       1     30
# 153291                                             no       2     36
# 153292                                             no       3     41
# 153293                                             no       4     42
# 153294                                             no       1    103
# 153295                                             no       2     74
# 153296                                             no       3     74
# 153297                                             no       1    107
# 153298  yes (cable modem, fiber optic or dsl service)       1    105
# 153299  yes (cable modem, fiber optic or dsl service)       2     99
# 153300                                       n/a (gq)       1     76
# 153301  yes (cable modem, fiber optic or dsl service)       1     50
# 153302  yes (cable modem, fiber optic or dsl service)       2     66
# 153303  yes (cable modem, fiber optic or dsl service)       1     65
# 153304  yes (cable modem, fiber optic or dsl service)       2     71
# ...                                               ...     ...    ...
# 530820                                       n/a (gq)       1     72
# 530821                                       n/a (gq)       1     40
# 530822                                       n/a (gq)       1    129
# 530823                                       n/a (gq)       1     17
# 530824                                       n/a (gq)       1    156
# 530825                                       n/a (gq)       1    149
# 530826                                       n/a (gq)       1     10
# 530827                                       n/a (gq)       1    114
# 530828                                       n/a (gq)       1     61
# 530829                                       n/a (gq)       1     28
# 530830                                       n/a (gq)       1     29
# 530831                                       n/a (gq)       1     17
# 530832                                       n/a (gq)       1     73
# 530833                                       n/a (gq)       1     22
# 530834                                       n/a (gq)       1    121
# 530835                                       n/a (gq)       1     19
# 530836                                       n/a (gq)       1     71
# 530837                                       n/a (gq)       1     50
# 530838                                       n/a (gq)       1     79
# 530839                                       n/a (gq)       1     21
# 530840                                       n/a (gq)       1     84
# 530841                                       n/a (gq)       1     12
# 530842                                       n/a (gq)       1     81
# 530843                                       n/a (gq)       1     33
# 530844                                       n/a (gq)       1     93
# 530845                                       n/a (gq)       1     25
# 530846                                       n/a (gq)       1     28
# 530847                                       n/a (gq)       1     41
# 530848                                       n/a (gq)       1     27
# 530849                                       n/a (gq)       1      6
#
#                           relate     sex age                             race  \
# 153275          head/householder    male  45                  two major races
# 153276                    spouse  female  39                  two major races
# 153277                     child    male  15                  two major races
# 153278          head/householder    male  34                          chinese
# 153279                    spouse  female  33                          chinese
# 153280                     child    male   4                          chinese
# 153281                     child    male   1                          chinese
# 153282          head/householder  female  76                            white
# 153283          head/householder    male  35  other asian or pacific islander
# 153284                    spouse  female  31  other asian or pacific islander
# 153285            sibling-in-law    male  21  other asian or pacific islander
# 153286          head/householder  female  66                            white
# 153287                    spouse    male  86                            white
# 153288          head/householder    male  47                            white
# 153289  partner, friend, visitor  female  41                            white
# 153290          head/householder  female  31                            white
# 153291                    spouse    male  34                            white
# 153292                     child  female  11                            white
# 153293                     child    male   7                            white
# 153294          head/householder    male  64                            white
# 153295                    spouse  female  57                            white
# 153296                     child  female  17                            white
# 153297          head/householder  female  70                            white
# 153298          head/householder  female  51                            white
# 153299                    spouse    male  31                            white
# 153300          head/householder  female  94                            white
# 153301          head/householder    male  80                            white
# 153302                    spouse  female  82        three or more major races
# 153303          head/householder    male  76                            white
# 153304                    spouse  female  65                            white
# ...                          ...     ...  ..                              ...
# 530820       other non-relatives    male  20                            white
# 530821       other non-relatives    male  19  other asian or pacific islander
# 530822       other non-relatives    male  27                            white
# 530823     institutional inmates  female  61     black/african american/negro
# 530824       other non-relatives  female  51                            white
# 530825       other non-relatives  female  59                            white
# 530826     institutional inmates    male  46     black/african american/negro
# 530827       other non-relatives    male  25                          chinese
# 530828     institutional inmates    male  50                            white
# 530829       other non-relatives  female  18                            white
# 530830     institutional inmates  female  73                            white
# 530831       other non-relatives  female  70                            white
# 530832     institutional inmates    male  34     black/african american/negro
# 530833     institutional inmates  female  88                          chinese
# 530834       other non-relatives  female  25                            white
# 530835     institutional inmates    male  48                            white
# 530836     institutional inmates    male  21     black/african american/negro
# 530837       other non-relatives  female  22                            white
# 530838     institutional inmates    male  37                            white
# 530839     institutional inmates  female  58     black/african american/negro
# 530840       other non-relatives  female  20  other asian or pacific islander
# 530841       other non-relatives  female  39                            white
# 530842     institutional inmates    male  48     black/african american/negro
# 530843       other non-relatives    male  19     black/african american/negro
# 530844     institutional inmates    male  28                            white
# 530845     institutional inmates    male  86                            white
# 530846     institutional inmates    male  32                            white
# 530847     institutional inmates    male  56                  other race, nec
# 530848     institutional inmates    male  26                  other race, nec
# 530849     institutional inmates    male  41                            white
#
#               hispan
# 153275  not hispanic
# 153276  not hispanic
# 153277  not hispanic
# 153278  not hispanic
# 153279  not hispanic
# 153280  not hispanic
# 153281  not hispanic
# 153282  not hispanic
# 153283  not hispanic
# 153284  not hispanic
# 153285  not hispanic
# 153286  not hispanic
# 153287  not hispanic
# 153288  not hispanic
# 153289  not hispanic
# 153290  not hispanic
# 153291  not hispanic
# 153292  not hispanic
# 153293  not hispanic
# 153294       mexican
# 153295  not hispanic
# 153296       mexican
# 153297  not hispanic
# 153298  not hispanic
# 153299  not hispanic
# 153300  not hispanic
# 153301  not hispanic
# 153302  not hispanic
# 153303  not hispanic
# 153304  not hispanic
# ...              ...
# 530820         other
# 530821  not hispanic
# 530822  not hispanic
# 530823  not hispanic
# 530824       mexican
# 530825  not hispanic
# 530826  not hispanic
# 530827  not hispanic
# 530828       mexican
# 530829       mexican
# 530830       mexican
# 530831  not hispanic
# 530832  puerto rican
# 530833  not hispanic
# 530834  not hispanic
# 530835       mexican
# 530836  not hispanic
# 530837  not hispanic
# 530838       mexican
# 530839  not hispanic
# 530840  not hispanic
# 530841  not hispanic
# 530842  not hispanic
# 530843  not hispanic
# 530844       mexican
# 530845  not hispanic
# 530846       mexican
# 530847       mexican
# 530848         other
# 530849       mexican
#
# [377575 rows x 14 columns]

# %%
state_data['gq'].unique()
# Out:
# [households under 1970 definition, additional households under 1990 definition, additional households under 2000 definition, group quarters--institutions, other group quarters]
# Categories (5, object): [households under 1970 definition < additional households under 1990 definition < group quarters--institutions < other group quarters < additional households under 2000 definition]

# %%
state_data['gq'].value_counts()
# Out:
# households under 1970 definition               359972
# other group quarters                             8392
# group quarters--institutions                     7575
# additional households under 1990 definition      1503
# additional households under 2000 definition       133
# Name: gq, dtype: int64

# %% [markdown]
# From IPUMS docs:
# >There are three slightly different definitions of group quarters in the IPUMS. For the period 1940-1970 (excluding the 1940 100% dataset), group quarters are housing units with five or more individuals unrelated to the householder. Before 1940 and in 1980-1990, units with 10 or more individuals unrelated to the householder are considered group quarters. **In the 2000 census, 2010 census, the ACS and the PRCS, no threshold was applied; for a household to be considered group quarters, it had to be on a list of group quarters that is continuously maintained by the Census Bureau. In earlier years, a similar list was used, with the unrelated-persons rule imposed as a safeguard.**

# %% [markdown]
# For this reason we will keep our analysis to households under the 1970 and 1990 definition.

# %% [markdown]
# conditional indexing - households under a certain household condition

# %%
# need to use parenthesis because of order of 
mask_household = (state_data['gq'] == 'households under 1970 definition') | (state_data['gq'] == 'additional households under 1990 definition')

# %% [markdown]
# Since `gq` is a categorical variable you could do the following
# ```python
# household_mask = (california_data['gq'] <= 'households under 1990 definition')
# ```

# %%
print(state_data.shape)
state_data = state_data[mask_household].copy()
print(state_data.shape)
# Out:
# (377575, 18)
# (361475, 18)

# %% [markdown]
# Let's drop those extra variables now.

# %%
state_data = state_data.drop(columns = ['gq', 'related', 'raced', 'hispand',])

# %% [markdown]
# indexing by another column: we want households with school-age children (18 or less)

# %% [markdown]
# What we need
# 1. the `serial` value for those households where school-age children exist
# 2. a mask that checks if the `serial` value of a household in our `california_data` is in our `households_with_children` dataset.
#
# The main challenge here is that the **unit of observation** in our `california_data` dataset is a person, whereas in our new `households_with_children` dataset the **unit of observation** will be a household.

# %%
# we use quotations because age is categorical right now. K-12 think 5 to 18
mask_children = (state_data['age'] <= '18') & (state_data['age'] >= '5')

# %%
households_with_children = state_data[mask_children].copy()
households_with_children.head()
# Out:
#         year  serial  hhwt    stateicp  countyfip  \
# 153277  2017   68211    59  california         67
# 153292  2017   68217    31  california         29
# 153293  2017   68217    31  california         29
# 153296  2017   68218   103  california         55
# 153320  2017   68229    50  california         37
#
#                                                 cinethh  \
# 153277  yes, with a subscription to an internet service
# 153292  yes, with a subscription to an internet service
# 153293  yes, with a subscription to an internet service
# 153296  yes, with a subscription to an internet service
# 153320  yes, with a subscription to an internet service
#
#                                             cihispeed  pernum  perwt  \
# 153277  yes (cable modem, fiber optic or dsl service)       3     54
# 153292                                             no       3     41
# 153293                                             no       4     42
# 153296                                             no       3     74
# 153320  yes (cable modem, fiber optic or dsl service)       4     50
#
#             relate     sex age             race        hispan
# 153277       child    male  15  two major races  not hispanic
# 153292       child  female  11            white  not hispanic
# 153293       child    male   7            white  not hispanic
# 153296       child  female  17            white       mexican
# 153320  grandchild    male   7            white       mexican

# %% [markdown]
# You'll notice that we have **duplicates** in our `serial` column. This is because it is possible to have more that one child living in a household. We're interested only in having a list of household `serial` values for those with children so we can ignore the rest of the columns.

# %%
households_with_children = households_with_children['serial']

# %% [markdown]
# Now, households_with_children is a pandas `Series` (not a dataframe anymore)

# %%
households_with_children.head()
# Out:
# 153277    68211
# 153292    68217
# 153293    68217
# 153296    68218
# 153320    68229
# Name: serial, dtype: int32

# %% [markdown]
# A series has an index and a value.

# %%
households_with_children.shape
# Out:
# (63415,)

# %% [markdown]
# Notice there's no 2nd value (number of columns). Series are one-dimensional.

# %%
households_with_children.drop_duplicates().shape
# Out:
# (36808,)

# %% [markdown]
# let's see what we know so far.

# %%
state_data.shape
# Out:
# (361475, 14)

# %%
n_obs = state_data.shape[0]
print(f"""
There are {n_obs:,} observations in our state_data dataset right now. 
The unit of observation here is a (weighted) person. 
That means there's {n_obs:,} thousand rows in our dataset but they represent more than 360 thousand people. 
In fact, they represent:
""")
# Out:
# There are 361,475 observations in our state_data dataset right now.
# The unit of observation here is a (weighted) person.
# That means there's 361,475 thousand rows in our dataset but they represent more than 360 thousand people.
# In fact, they represent:

# %%
state_data['perwt'].sum()
# Out:
# 38704629

# %%
n_people = state_data['perwt'].sum()
_state = state_data['stateicp'].unique()[0]
print(f"""
{n_people:,} in {_state.capitalize()}. 
Working with weighted data may be tricky for those who've never encountered it before. 
ADD MORE TEXT ABOUT WEGHTED DATA
""")
# Out:
# 38,704,629 in California.
# Working with weighted data may be tricky for those who've never encountered it before.
# ADD MORE TEXT ABOUT WEGHTED DATA

# %% [markdown]
# Second step in our indexing:

# %%
# .isin()
mask_households_with_children = state_data['serial'].isin(households_with_children)

# %%
state_data[mask_households_with_children].head()
# Out:
#          year  serial  hhwt stateicp  countyfip  \
# 2185117  2017  953662    57     ohio          0
# 2185118  2017  953662    57     ohio          0
# 2185119  2017  953662    57     ohio          0
# 2185128  2017  953668   140     ohio         61
# 2185129  2017  953668   140     ohio         61
#
#                                                  cinethh  \
# 2185117  yes, with a subscription to an internet service
# 2185118  yes, with a subscription to an internet service
# 2185119  yes, with a subscription to an internet service
# 2185128  yes, with a subscription to an internet service
# 2185129  yes, with a subscription to an internet service
#
#                                              cihispeed  pernum  perwt  \
# 2185117  yes (cable modem, fiber optic or dsl service)       1     58
# 2185118  yes (cable modem, fiber optic or dsl service)       2     62
# 2185119  yes (cable modem, fiber optic or dsl service)       3     78
# 2185128  yes (cable modem, fiber optic or dsl service)       1    140
# 2185129  yes (cable modem, fiber optic or dsl service)       2    192
#
#                    relate     sex age                          race  \
# 2185117  head/householder  female  48                         white
# 2185118             child    male  20                         white
# 2185119             child  female   9                         white
# 2185128  head/householder    male  28  black/african american/negro
# 2185129           sibling  female  16  black/african american/negro
#
#                hispan
# 2185117  not hispanic
# 2185118  not hispanic
# 2185119  not hispanic
# 2185128  not hispanic
# 2185129  not hispanic

# %% [markdown]
# Now we have a _working dataset_! We've taken what we **need** from the main dataset.

# %%
working_dataset = state_data[mask_households_with_children].copy()

# %% [markdown]
# Now we have a working dataset:
# 1. We chose one state to look at.
# 2. We dropped any unnecessary variables.
# 3. We chose the observations we're interested in
#     * Households (under a specific definition)
#     * Out of those households, only those with school-age children.

# %% [markdown]
# No we might be tempted to continue working on this notebook but a good way to keep your analyses reproducible and organized is to separate them by tasks done. This notebook created a clean working dataset for our analysis and that's all it should do. Let's save our data and move on to the next notebook now.

# %% [markdown]
# We can save data in a variety of formats with pandas. 2 of the most common in social sciences are `.csv` (comma-separated values) files and `.dta` (STATA) files.
#
# CSV files are text files. Pandas can ___guess___ the data types of each column but this information isn't stored in the file. STATA files, in the other hand, do contain metadata. If you have categorical variables in your data, you can save those as categorical columns in your STATA file. This saves memory. However, `JupyterLab`
#
# ADD MORE ABOUT CSV AND STATA SAVING DATA ETC

# %%
working_dataset.to_stata(INTERIM_DATA_FOLDER / f'working_dataset-{today}.dta', write_index = False)
