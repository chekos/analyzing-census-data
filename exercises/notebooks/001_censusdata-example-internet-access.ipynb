# %% [markdown]
# # `censusdata` example
#
# Docs: https://jtleider.github.io/censusdata/
#
# ```shell
# pip install --user censusdata
# ```

# %%
import censusdata
import pandas as pd

# %%
# the last five labels that have the word unemploy in them
censusdata.search(src='acs1', year = 2017, field = 'label', criterion = 'internet' )
# Out:
# [('B24030_083E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Information!!Broadcasting, internet publishing, and telecommunications services'),
#  ('B24030_187E',
#   'SEX BY INDUSTRY FOR THE CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Information!!Broadcasting, internet publishing, and telecommunications services'),
#  ('B24040_083E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Male!!Information!!Broadcasting, internet publishing, and telecommunications services'),
#  ('B24040_187E',
#   'SEX BY INDUSTRY FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER',
#   'Estimate!!Total!!Female!!Information!!Broadcasting, internet publishing, and telecommunications services'),
#  ('B28002_002E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription'),
#  ('B28002_003E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Dial-up with no other type of Internet subscription'),
#  ('B28002_004E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Broadband of any type'),
#  ('B28002_005E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Cellular data plan'),
#  ('B28002_006E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Cellular data plan!!Cellular data plan with no other type of Internet subscription'),
#  ('B28002_007E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL'),
#  ('B28002_008E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic or DSL!!Broadband such as cable, fiber optic or DSL with no other type of Internet subscription'),
#  ('B28002_009E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
#  ('B28002_010E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Satellite Internet service!!Satellite Internet service with no other type of Internet subscription'),
#  ('B28002_011E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Other service with no other type of Internet subscription'),
#  ('B28002_012E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!Internet access without a subscription'),
#  ('B28002_013E',
#   'PRESENCE AND TYPES OF INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!No Internet access'),
#  ('B28003_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28003_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28003_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28004_003E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Less than $10,000!!With dial-up Internet subscription alone'),
#  ('B28004_004E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Less than $10,000!!With a broadband Internet subscription'),
#  ('B28004_005E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Less than $10,000!!Without an Internet subscription'),
#  ('B28004_007E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$10,000 to $19,999!!With dial-up Internet subscription alone'),
#  ('B28004_008E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$10,000 to $19,999!!With a broadband Internet subscription'),
#  ('B28004_009E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$10,000 to $19,999!!Without an Internet subscription'),
#  ('B28004_011E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$20,000 to $34,999!!With dial-up Internet subscription alone'),
#  ('B28004_012E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$20,000 to $34,999!!With a broadband Internet subscription'),
#  ('B28004_013E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$20,000 to $34,999!!Without an Internet subscription'),
#  ('B28004_015E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$35,000 to $49,999!!With dial-up Internet subscription alone'),
#  ('B28004_016E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$35,000 to $49,999!!With a broadband Internet subscription'),
#  ('B28004_017E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$35,000 to $49,999!!Without an Internet subscription'),
#  ('B28004_019E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$50,000 to $74,999!!With dial-up Internet subscription alone'),
#  ('B28004_020E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$50,000 to $74,999!!With a broadband Internet subscription'),
#  ('B28004_021E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$50,000 to $74,999!!Without an Internet subscription'),
#  ('B28004_023E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$75,000 or more!!With dial-up Internet subscription alone'),
#  ('B28004_024E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$75,000 or more!!With a broadband Internet subscription'),
#  ('B28004_025E',
#   'HOUSEHOLD INCOME IN THE LAST 12 MONTHS (IN 2017 INFLATION-ADJUSTED DOLLARS) BY PRESENCE AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!$75,000 or more!!Without an Internet subscription'),
#  ('B28005_004E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Under 18 years!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28005_005E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Under 18 years!!Has a computer!!With a broadband Internet subscription'),
#  ('B28005_006E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Under 18 years!!Has a computer!!Without an Internet subscription'),
#  ('B28005_010E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!18 to 64 years!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28005_011E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!18 to 64 years!!Has a computer!!With a broadband Internet subscription'),
#  ('B28005_012E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!18 to 64 years!!Has a computer!!Without an Internet subscription'),
#  ('B28005_016E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!65 years and over!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28005_017E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!65 years and over!!Has a computer!!With a broadband Internet subscription'),
#  ('B28005_018E',
#   'AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!65 years and over!!Has a computer!!Without an Internet subscription'),
#  ('B28006_004E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28006_005E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!With a broadband Internet subscription'),
#  ('B28006_006E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Less than high school graduate or equivalency!!Has a computer!!Without an Internet subscription'),
#  ('B28006_010E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   "Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With dial-up Internet subscription alone"),
#  ('B28006_011E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   "Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!With a broadband Internet subscription"),
#  ('B28006_012E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   "Estimate!!Total!!High school graduate (includes equivalency) , some college or associate's degree!!Has a computer!!Without an Internet subscription"),
#  ('B28006_016E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   "Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!With dial-up Internet subscription alone"),
#  ('B28006_017E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   "Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!With a broadband Internet subscription"),
#  ('B28006_018E',
#   'EDUCATIONAL ATTAINMENT BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   "Estimate!!Total!!Bachelor's degree or higher!!Has a computer!!Without an Internet subscription"),
#  ('B28007_005E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28007_006E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!With a broadband Internet subscription'),
#  ('B28007_007E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!In the civilian labor force!!Employed!!Has a computer!!Without an Internet subscription'),
#  ('B28007_011E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28007_012E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!With a broadband Internet subscription'),
#  ('B28007_013E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!In the civilian labor force!!Unemployed!!Has a computer!!Without an Internet subscription'),
#  ('B28007_017E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Not in labor force!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28007_018E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Not in labor force!!Has a computer!!With a broadband Internet subscription'),
#  ('B28007_019E',
#   'LABOR FORCE STATUS BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Not in labor force!!Has a computer!!Without an Internet subscription'),
#  ('B28008_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28008_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription'),
#  ('B28008_006E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!With a cellular data plan'),
#  ('B28008_007E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!With a broadband subscription!!With a fixed broadband Internet subscription!!Without a cellular data plan'),
#  ('B28008_009E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD',
#   'Estimate!!Total!!Has a computer!!Without Internet subscription'),
#  ('B28009A_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009A_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009A_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009B_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009B_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009B_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (BLACK OR AFRICAN AMERICAN ALONE)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009C_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009C_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009C_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (AMERICAN INDIAN AND ALASKA NATIVE ALONE)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009D_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (ASIAN ALONE)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009D_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (ASIAN ALONE)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009D_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (ASIAN ALONE)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009E_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009E_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009E_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (NATIVE HAWAIIAN AND OTHER PACIFIC ISLANDER ALONE)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009F_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (SOME OTHER RACE ALONE)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009F_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (SOME OTHER RACE ALONE)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009F_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (SOME OTHER RACE ALONE)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009G_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (TWO OR MORE RACES)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009G_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (TWO OR MORE RACES)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009G_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (TWO OR MORE RACES)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009H_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009H_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009H_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE, NOT HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28009I_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009I_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009I_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),
#  ('B28011_002E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription'),
#  ('B28011_003E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Dial-up alone'),
#  ('B28011_004E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic, or DSL'),
#  ('B28011_005E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
#  ('B28011_006E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!With an Internet subscription!!Other service'),
#  ('B28011_007E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!Internet access without a subscription'),
#  ('B28011_008E',
#   'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
#   'Estimate!!Total!!No Internet access')]

# %%
# you can search by "concept"
censusdata.search(src = 'acs1', year = 2015, field = 'concept', criterion = 'internet')
# Out:
# [('B28002_001E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Total:'),
#  ('B28002_001M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!Total:'),
#  ('B28002_002E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:'),
#  ('B28002_002M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:'),
#  ('B28002_003E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Dial-up alone'),
#  ('B28002_003M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Dial-up alone'),
#  ('B28002_004E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!DSL:'),
#  ('B28002_004M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!DSL:'),
#  ('B28002_005E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!DSL:!!With mobile broadband'),
#  ('B28002_005M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!DSL:!!With mobile broadband'),
#  ('B28002_006E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!DSL:!!Without mobile broadband'),
#  ('B28002_006M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!DSL:!!Without mobile broadband'),
#  ('B28002_007E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Cable modem:'),
#  ('B28002_007M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Cable modem:'),
#  ('B28002_008E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Cable modem:!!With mobile broadband'),
#  ('B28002_008M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Cable modem:!!With mobile broadband'),
#  ('B28002_009E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Cable modem:!!Without mobile broadband'),
#  ('B28002_009M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Cable modem:!!Without mobile broadband'),
#  ('B28002_010E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Fiber-optic:'),
#  ('B28002_010M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Fiber-optic:'),
#  ('B28002_011E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Fiber-optic:!!With mobile broadband'),
#  ('B28002_011M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Fiber-optic:!!With mobile broadband'),
#  ('B28002_012E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Fiber-optic:!!Without mobile broadband'),
#  ('B28002_012M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Fiber-optic:!!Without mobile broadband'),
#  ('B28002_013E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Satellite Internet service:'),
#  ('B28002_013M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Satellite Internet service:'),
#  ('B28002_014E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Satellite Internet service:!!With mobile broadband'),
#  ('B28002_014M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Satellite Internet service:!!With mobile broadband'),
#  ('B28002_015E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Satellite Internet service:!!Without mobile broadband'),
#  ('B28002_015M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Satellite Internet service:!!Without mobile broadband'),
#  ('B28002_016E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Two or more fixed broadband types, or other:'),
#  ('B28002_016M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Two or more fixed broadband types, or other:'),
#  ('B28002_017E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Two or more fixed broadband types, or other:!!With mobile broadband'),
#  ('B28002_017M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Two or more fixed broadband types, or other:!!With mobile broadband'),
#  ('B28002_018E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Two or more fixed broadband types, or other:!!Without mobile broadband'),
#  ('B28002_018M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Two or more fixed broadband types, or other:!!Without mobile broadband'),
#  ('B28002_019E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'With an Internet subscription:!!Mobile broadband alone or with dialup'),
#  ('B28002_019M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!With an Internet subscription:!!Mobile broadband alone or with dialup'),
#  ('B28002_020E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Internet access without a subscription'),
#  ('B28002_020M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!Internet access without a subscription'),
#  ('B28002_021E',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'No Internet access'),
#  ('B28002_021M',
#   'B28002.  Presence and Types of Internet Subscriptions in Household',
#   'Margin of Error for!!No Internet access'),
#  ('B28003_001E',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Total:'),
#  ('B28003_001M',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Margin of Error for!!Total:'),
#  ('B28003_002E',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Has a computer:'),
#  ('B28003_002M',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Margin of Error for!!Has a computer:'),
#  ('B28003_003E',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28003_003M',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28003_004E',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28003_004M',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28003_005E',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28003_005M',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28003_006E',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'No computer'),
#  ('B28003_006M',
#   'B28003.  Presence of a Computer and Type of Internet Subscripton in Household',
#   'Margin of Error for!!No computer'),
#  ('B28004_001E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Total:'),
#  ('B28004_001M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!Total:'),
#  ('B28004_002E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Less than $10,000:'),
#  ('B28004_002M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!Less than $10,000:'),
#  ('B28004_003E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Less than $10,000:!!With dial-up Internet subscription alone'),
#  ('B28004_003M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!Less than $10,000:!!With dial-up Internet subscription alone'),
#  ('B28004_004E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Less than $10,000:!!With a broadband Internet subscription'),
#  ('B28004_004M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!Less than $10,000:!!With a broadband Internet subscription'),
#  ('B28004_005E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Less than $10,000:!!Without an Internet subscription'),
#  ('B28004_005M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!Less than $10,000:!!Without an Internet subscription'),
#  ('B28004_006E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$10,000 to $19,999:'),
#  ('B28004_006M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$10,000 to $19,999:'),
#  ('B28004_007E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$10,000 to $19,999:!!With dial-up Internet subscription alone'),
#  ('B28004_007M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$10,000 to $19,999:!!With dial-up Internet subscription alone'),
#  ('B28004_008E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$10,000 to $19,999:!!With a broadband Internet subscription'),
#  ('B28004_008M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$10,000 to $19,999:!!With a broadband Internet subscription'),
#  ('B28004_009E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$10,000 to $19,999:!!Without an Internet subscription'),
#  ('B28004_009M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$10,000 to $19,999:!!Without an Internet subscription'),
#  ('B28004_010E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$20,000 to $34,999:'),
#  ('B28004_010M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$20,000 to $34,999:'),
#  ('B28004_011E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$20,000 to $34,999:!!With dial-up Internet subscription alone'),
#  ('B28004_011M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$20,000 to $34,999:!!With dial-up Internet subscription alone'),
#  ('B28004_012E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$20,000 to $34,999:!!With a broadband Internet subscription'),
#  ('B28004_012M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$20,000 to $34,999:!!With a broadband Internet subscription'),
#  ('B28004_013E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$20,000 to $34,999:!!Without an Internet subscription'),
#  ('B28004_013M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$20,000 to $34,999:!!Without an Internet subscription'),
#  ('B28004_014E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$35,000 to $49,999:'),
#  ('B28004_014M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$35,000 to $49,999:'),
#  ('B28004_015E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$35,000 to $49,999:!!With dial-up Internet subscription alone'),
#  ('B28004_015M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$35,000 to $49,999:!!With dial-up Internet subscription alone'),
#  ('B28004_016E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$35,000 to $49,999:!!With a broadband Internet subscription'),
#  ('B28004_016M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$35,000 to $49,999:!!With a broadband Internet subscription'),
#  ('B28004_017E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$35,000 to $49,999:!!Without an Internet subscription'),
#  ('B28004_017M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$35,000 to $49,999:!!Without an Internet subscription'),
#  ('B28004_018E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$50,000 to $74,999:'),
#  ('B28004_018M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$50,000 to $74,999:'),
#  ('B28004_019E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$50,000 to $74,999:!!With dial-up Internet subscription alone'),
#  ('B28004_019M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$50,000 to $74,999:!!With dial-up Internet subscription alone'),
#  ('B28004_020E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$50,000 to $74,999:!!With a broadband Internet subscription'),
#  ('B28004_020M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$50,000 to $74,999:!!With a broadband Internet subscription'),
#  ('B28004_021E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$50,000 to $74,999:!!Without an Internet subscription'),
#  ('B28004_021M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$50,000 to $74,999:!!Without an Internet subscription'),
#  ('B28004_022E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$75,000 or more:'),
#  ('B28004_022M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$75,000 or more:'),
#  ('B28004_023E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$75,000 or more:!!With dial-up Internet subscription alone'),
#  ('B28004_023M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$75,000 or more:!!With dial-up Internet subscription alone'),
#  ('B28004_024E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$75,000 or more:!!With a broadband Internet subscription'),
#  ('B28004_024M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$75,000 or more:!!With a broadband Internet subscription'),
#  ('B28004_025E',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   '$75,000 or more:!!Without an Internet subscription'),
#  ('B28004_025M',
#   'B28004. Household Income in the Last 12 Months (in 2015 Inflation-Adjusted Dollars) by Presence and Type of Internet Subscription in Household',
#   'Margin of Error for!!$75,000 or more:!!Without an Internet subscription'),
#  ('B28005_001E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Total:'),
#  ('B28005_001M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Total:'),
#  ('B28005_002E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Under 18 years:'),
#  ('B28005_002M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Under 18 years:'),
#  ('B28005_003E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Under 18 years:!!Has a computer:'),
#  ('B28005_003M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Under 18 years:!!Has a computer:'),
#  ('B28005_004E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Under 18 years:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28005_004M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Under 18 years:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28005_005E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Under 18 years:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28005_005M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Under 18 years:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28005_006E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Under 18 years:!!Has a computer:!!Without an Internet subscription'),
#  ('B28005_006M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Under 18 years:!!Has a computer:!!Without an Internet subscription'),
#  ('B28005_007E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Under 18 years:!!No computer'),
#  ('B28005_007M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Under 18 years:!!No computer'),
#  ('B28005_008E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '18 to 64 years:'),
#  ('B28005_008M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!18 to 64 years:'),
#  ('B28005_009E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '18 to 64 years:!!Has a computer:'),
#  ('B28005_009M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!18 to 64 years:!!Has a computer:'),
#  ('B28005_010E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '18 to 64 years:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28005_010M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!18 to 64 years:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28005_011E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '18 to 64 years:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28005_011M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!18 to 64 years:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28005_012E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '18 to 64 years:!!Has a computer:!!Without an Internet subscription'),
#  ('B28005_012M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!18 to 64 years:!!Has a computer:!!Without an Internet subscription'),
#  ('B28005_013E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '18 to 64 years:!!No computer'),
#  ('B28005_013M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!18 to 64 years:!!No computer'),
#  ('B28005_014E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '65 years and over:'),
#  ('B28005_014M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!65 years and over:'),
#  ('B28005_015E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '65 years and over:!!Has a computer:'),
#  ('B28005_015M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!65 years and over:!!Has a computer:'),
#  ('B28005_016E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '65 years and over:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28005_016M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!65 years and over:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28005_017E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '65 years and over:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28005_017M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!65 years and over:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28005_018E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '65 years and over:!!Has a computer:!!Without an Internet subscription'),
#  ('B28005_018M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!65 years and over:!!Has a computer:!!Without an Internet subscription'),
#  ('B28005_019E',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   '65 years and over:!!No computer'),
#  ('B28005_019M',
#   'B28005.  Age by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!65 years and over:!!No computer'),
#  ('B28006_001E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Total:'),
#  ('B28006_001M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Total:'),
#  ('B28006_002E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Less than high school graduate or equivalency:'),
#  ('B28006_002M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Less than high school graduate or equivalency:'),
#  ('B28006_003E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Less than high school graduate or equivalency:!!Has a computer:'),
#  ('B28006_003M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Less than high school graduate or equivalency:!!Has a computer:'),
#  ('B28006_004E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Less than high school graduate or equivalency:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28006_004M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Less than high school graduate or equivalency:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28006_005E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Less than high school graduate or equivalency:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28006_005M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Less than high school graduate or equivalency:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28006_006E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Less than high school graduate or equivalency:!!Has a computer:!!Without an Internet subscription'),
#  ('B28006_006M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Less than high school graduate or equivalency:!!Has a computer:!!Without an Internet subscription'),
#  ('B28006_007E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Less than high school graduate or equivalency:!!No computer'),
#  ('B28006_007M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Less than high school graduate or equivalency:!!No computer'),
#  ('B28006_008E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "High school graduate (includes equivalency) , some college or associate's degree :"),
#  ('B28006_008M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!High school graduate (includes equivalency) , some college or associate's degree :"),
#  ('B28006_009E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:"),
#  ('B28006_009M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:"),
#  ('B28006_010E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:!!With dial-up Internet subscription alone"),
#  ('B28006_010M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:!!With dial-up Internet subscription alone"),
#  ('B28006_011E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:!!With a broadband Internet subscription"),
#  ('B28006_011M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:!!With a broadband Internet subscription"),
#  ('B28006_012E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:!!Without an Internet subscription"),
#  ('B28006_012M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!High school graduate (includes equivalency) , some college or associate's degree :!!Has a computer:!!Without an Internet subscription"),
#  ('B28006_013E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "High school graduate (includes equivalency) , some college or associate's degree :!!No computer"),
#  ('B28006_013M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!High school graduate (includes equivalency) , some college or associate's degree :!!No computer"),
#  ('B28006_014E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Bachelor's degree or higher:"),
#  ('B28006_014M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!Bachelor's degree or higher:"),
#  ('B28006_015E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Bachelor's degree or higher:!!Has a computer:"),
#  ('B28006_015M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!Bachelor's degree or higher:!!Has a computer:"),
#  ('B28006_016E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Bachelor's degree or higher:!!Has a computer:!!With dial-up Internet subscription alone"),
#  ('B28006_016M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!Bachelor's degree or higher:!!Has a computer:!!With dial-up Internet subscription alone"),
#  ('B28006_017E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Bachelor's degree or higher:!!Has a computer:!!With a broadband Internet subscription"),
#  ('B28006_017M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!Bachelor's degree or higher:!!Has a computer:!!With a broadband Internet subscription"),
#  ('B28006_018E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Bachelor's degree or higher:!!Has a computer:!!Without an Internet subscription"),
#  ('B28006_018M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!Bachelor's degree or higher:!!Has a computer:!!Without an Internet subscription"),
#  ('B28006_019E',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Bachelor's degree or higher:!!No computer"),
#  ('B28006_019M',
#   'B28006.  Educational Attainment by Presence of a Computer and Types of Internet Subscription in Household',
#   "Margin of Error for!!Bachelor's degree or higher:!!No computer"),
#  ('B28007_001E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Total:'),
#  ('B28007_001M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Total:'),
#  ('B28007_002E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:'),
#  ('B28007_002M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:'),
#  ('B28007_003E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Employed:'),
#  ('B28007_003M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Employed:'),
#  ('B28007_004E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Employed:!!Has a computer:'),
#  ('B28007_004M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Employed:!!Has a computer:'),
#  ('B28007_005E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Employed:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28007_005M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Employed:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28007_006E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Employed:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28007_006M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Employed:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28007_007E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Employed:!!Has a computer:!!Without an Internet subscription'),
#  ('B28007_007M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Employed:!!Has a computer:!!Without an Internet subscription'),
#  ('B28007_008E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Employed:!!No computer'),
#  ('B28007_008M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Employed:!!No computer'),
#  ('B28007_009E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Unemployed:'),
#  ('B28007_009M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Unemployed:'),
#  ('B28007_010E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Unemployed:!!Has a computer:'),
#  ('B28007_010M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Unemployed:!!Has a computer:'),
#  ('B28007_011E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Unemployed:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28007_011M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Unemployed:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28007_012E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Unemployed:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28007_012M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Unemployed:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28007_013E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Unemployed:!!Has a computer:!!Without an Internet subscription'),
#  ('B28007_013M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Unemployed:!!Has a computer:!!Without an Internet subscription'),
#  ('B28007_014E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'In the civilian labor force:!!Unemployed:!!No computer'),
#  ('B28007_014M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!In the civilian labor force:!!Unemployed:!!No computer'),
#  ('B28007_015E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Not in labor force:'),
#  ('B28007_015M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Not in labor force:'),
#  ('B28007_016E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Not in labor force:!!Has a computer:'),
#  ('B28007_016M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Not in labor force:!!Has a computer:'),
#  ('B28007_017E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Not in labor force:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28007_017M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Not in labor force:!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28007_018E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Not in labor force:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28007_018M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Not in labor force:!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28007_019E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Not in labor force:!!Has a computer:!!Without an Internet subscription'),
#  ('B28007_019M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Not in labor force:!!Has a computer:!!Without an Internet subscription'),
#  ('B28007_020E',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Not in labor force:!!No computer'),
#  ('B28007_020M',
#   'B28007.  Labor Force Status by Presence of a Computer and Types of Internet Subscription in Household',
#   'Margin of Error for!!Not in labor force:!!No computer'),
#  ('B28008_001E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Total:'),
#  ('B28008_001M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Total:'),
#  ('B28008_002E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:'),
#  ('B28008_002M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:'),
#  ('B28008_003E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28008_003M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28008_004E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!With a broadband subscription:'),
#  ('B28008_004M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!With a broadband subscription:'),
#  ('B28008_005E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!With a broadband subscription:!!With a fixed broadband Internet subscription:'),
#  ('B28008_005M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!With a broadband subscription:!!With a fixed broadband Internet subscription:'),
#  ('B28008_006E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!With a broadband subscription:!!With a fixed broadband Internet subscription:!!With mobile broadband subscription'),
#  ('B28008_006M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!With a broadband subscription:!!With a fixed broadband Internet subscription:!!With mobile broadband subscription'),
#  ('B28008_007E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!With a broadband subscription:!!With a fixed broadband Internet subscription:!!Without mobile broadband subscription'),
#  ('B28008_007M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!With a broadband subscription:!!With a fixed broadband Internet subscription:!!Without mobile broadband subscription'),
#  ('B28008_008E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!With a broadband subscription:!!Mobile broadband subscription alone or with dial-up'),
#  ('B28008_008M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!With a broadband subscription:!!Mobile broadband subscription alone or with dial-up'),
#  ('B28008_009E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Has a computer:!!Without Internet subscription'),
#  ('B28008_009M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!Has a computer:!!Without Internet subscription'),
#  ('B28008_010E',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'No Computer'),
#  ('B28008_010M',
#   'B28008.  Presence of a Computer and Type of Internet Subscription in Household',
#   'Margin of Error for!!No Computer'),
#  ('B28009A_001E',
#   'B28009A.  Presence of a Computer and Type of Internet Subscription in Household (White alone)',
#   'Total:'),
#  ('B28009A_001M',
#   'B28009A.  Presence of a Computer and Type of Internet Subscription in Household (White alone)',
#   'Margin of Error for!!Total:'),
#  ('B28009A_002E',
#   'B28009A.  Presence of a Computer and Type of Internet Subscription in Household (White alone)',
#   'Has a computer:'),
#  ('B28009A_002M',
#   'B28009A.  Presence of a Computer and Type of Internet Subscription in Household (White alone)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009A_003E',
#   'B28009A.  Presence of a Computer and Type of Internet Subscription in Household (White alone)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009A_003M',
#   'B28009A.  Presence of a Computer and Type of Internet Subscription in Household (White alone)',
# ...
#   'Margin of Error for!!Total:'),
#  ('B28009C_002E',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Has a computer:'),
#  ('B28009C_002M',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009C_003E',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009C_003M',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009C_004E',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009C_004M',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009C_005E',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009C_005M',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009C_006E',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'No Computer'),
#  ('B28009C_006M',
#   'B28009C.  Presence of a Computer and Type of Internet Subscription in Household (American Indian and Alaska Native alone)',
#   'Margin of Error for!!No Computer'),
#  ('B28009D_001E',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Total:'),
#  ('B28009D_001M',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Margin of Error for!!Total:'),
#  ('B28009D_002E',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Has a computer:'),
#  ('B28009D_002M',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009D_003E',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009D_003M',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009D_004E',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009D_004M',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009D_005E',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009D_005M',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009D_006E',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'No Computer'),
#  ('B28009D_006M',
#   'B28009D.  Presence of a Computer and Type of Internet Subscription in Household (Asian alone)',
#   'Margin of Error for!!No Computer'),
#  ('B28009E_001E',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Total:'),
#  ('B28009E_001M',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Margin of Error for!!Total:'),
#  ('B28009E_002E',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Has a computer:'),
#  ('B28009E_002M',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009E_003E',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009E_003M',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009E_004E',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009E_004M',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009E_005E',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009E_005M',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009E_006E',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'No Computer'),
#  ('B28009E_006M',
#   'B28009E.  Presence of a Computer and Type of Internet Subscription in Household (Native Hawaiian and Other Pacific Islander alone)',
#   'Margin of Error for!!No Computer'),
#  ('B28009F_001E',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Total:'),
#  ('B28009F_001M',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Margin of Error for!!Total:'),
#  ('B28009F_002E',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Has a computer:'),
#  ('B28009F_002M',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009F_003E',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009F_003M',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009F_004E',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009F_004M',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009F_005E',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009F_005M',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009F_006E',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'No Computer'),
#  ('B28009F_006M',
#   'B28009F.  Presence of a Computer and Type of Internet Subscription in Household (Some other race alone)',
#   'Margin of Error for!!No Computer'),
#  ('B28009G_001E',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Total:'),
#  ('B28009G_001M',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Margin of Error for!!Total:'),
#  ('B28009G_002E',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Has a computer:'),
#  ('B28009G_002M',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009G_003E',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009G_003M',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009G_004E',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009G_004M',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009G_005E',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009G_005M',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009G_006E',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'No Computer'),
#  ('B28009G_006M',
#   'B28009G.  Presence of a Computer and Type of Internet Subscription in Household (Two or more races)',
#   'Margin of Error for!!No Computer'),
#  ('B28009H_001E',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Total:'),
#  ('B28009H_001M',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Margin of Error for!!Total:'),
#  ('B28009H_002E',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Has a computer:'),
#  ('B28009H_002M',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009H_003E',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009H_003M',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009H_004E',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009H_004M',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009H_005E',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009H_005M',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009H_006E',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'No Computer'),
#  ('B28009H_006M',
#   'B28009H.  Presence of a Computer and Type of Internet Subscription in Household (White alone, not Hispanic or Latino)',
#   'Margin of Error for!!No Computer'),
#  ('B28009I_001E',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Total:'),
#  ('B28009I_001M',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Margin of Error for!!Total:'),
#  ('B28009I_002E',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Has a computer:'),
#  ('B28009I_002M',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:'),
#  ('B28009I_003E',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009I_003M',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:!!With dial-up Internet subscription alone'),
#  ('B28009I_004E',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Has a computer:!!With a broadband Internet subscription'),
#  ('B28009I_004M',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:!!With a broadband Internet subscription'),
#  ('B28009I_005E',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Has a computer:!!Without an Internet subscription'),
#  ('B28009I_005M',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Margin of Error for!!Has a computer:!!Without an Internet subscription'),
#  ('B28009I_006E',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'No Computer'),
#  ('B28009I_006M',
#   'B28009I.  Presence of a Computer and Type of Internet Subscription in Household (Hispanic or Latino)',
#   'Margin of Error for!!No Computer'),
#  ('B99281_001E', 'B99281.  Imputation of Household Internet Access', 'Total:'),
#  ('B99281_002E',
#   'B99281.  Imputation of Household Internet Access',
#   'Imputed'),
#  ('B99281_003E',
#   'B99281.  Imputation of Household Internet Access',
#   'Not imputed'),
#  ('B99283_001E',
#   'B99283.  Imputation of Household Internet Subscription Type',
#   'Total:'),
#  ('B99283_002E',
#   'B99283.  Imputation of Household Internet Subscription Type',
#   'Imputed:!!Dial-up'),
#  ('B99283_003E',
#   'B99283.  Imputation of Household Internet Subscription Type',
#   'Imputed:!!DSL'),
#  ('B99283_004E',
#   'B99283.  Imputation of Household Internet Subscription Type',
#   'Imputed:!!Cable modem, fiber-optic, satellite internet service and some other service'),
#  ('B99283_005E',
#   'B99283.  Imputation of Household Internet Subscription Type',
#   'Imputed:!!Mobile broadband'),
#  ('B99283_006E',
#   'B99283.  Imputation of Household Internet Subscription Type',
#   'Not imputed')]

# %% [markdown]
# ('B28009I_003E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
#  ('B28009I_004E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
#  ('B28009I_005E',
#   'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
#   'Estimate!!Total!!Has a computer!!Without an Internet subscription'),

# %%
# you can grab tables if you know what you are looking for
censusdata.censustable(src = 'acs5', year = 2015, table = 'B28009')
# Out:
# Table not found!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-bc1f49680288> in <module>
#       1 # you can grab tables if you know what you are looking for
# ----> 2 censusdata.censustable(src = 'acs5', year = 2015, table = 'B28009')
#
# ~\AppData\Local\Continuum\anaconda3\envs\pycon2019\lib\site-packages\censusdata\variable_info.py in censustable(src, year, table)
#     108         if len(ret) == 0:
#     109                 print(u'Table not found!')
# --> 110                 raise ValueError
#     111         return ret
#     112
#
# ValueError:

# %%
#and print them legibly
censusdata.printtable(censusdata.censustable(src = 'acs5', year = 2015, table = 'B15003'))
# Out:
# Variable     | Table                          | Label                                                    | Type
# -------------------------------------------------------------------------------------------------------------------
# B15003_001E  | B15003.  Educational Attainmen | Total:                                                   | int
# B15003_002E  | B15003.  Educational Attainmen | No schooling completed                                   | int
# B15003_003E  | B15003.  Educational Attainmen | Nursery school                                           | int
# B15003_004E  | B15003.  Educational Attainmen | Kindergarten                                             | int
# B15003_005E  | B15003.  Educational Attainmen | 1st grade                                                | int
# B15003_006E  | B15003.  Educational Attainmen | 2nd grade                                                | int
# B15003_007E  | B15003.  Educational Attainmen | 3rd grade                                                | int
# B15003_008E  | B15003.  Educational Attainmen | 4th grade                                                | int
# B15003_009E  | B15003.  Educational Attainmen | 5th grade                                                | int
# B15003_010E  | B15003.  Educational Attainmen | 6th grade                                                | int
# B15003_011E  | B15003.  Educational Attainmen | 7th grade                                                | int
# B15003_012E  | B15003.  Educational Attainmen | 8th grade                                                | int
# B15003_013E  | B15003.  Educational Attainmen | 9th grade                                                | int
# B15003_014E  | B15003.  Educational Attainmen | 10th grade                                               | int
# B15003_015E  | B15003.  Educational Attainmen | 11th grade                                               | int
# B15003_016E  | B15003.  Educational Attainmen | 12th grade, no diploma                                   | int
# B15003_017E  | B15003.  Educational Attainmen | Regular high school diploma                              | int
# B15003_018E  | B15003.  Educational Attainmen | GED or alternative credential                            | int
# B15003_019E  | B15003.  Educational Attainmen | Some college, less than 1 year                           | int
# B15003_020E  | B15003.  Educational Attainmen | Some college, 1 or more years, no degree                 | int
# B15003_021E  | B15003.  Educational Attainmen | Associate's degree                                       | int
# B15003_022E  | B15003.  Educational Attainmen | Bachelor's degree                                        | int
# B15003_023E  | B15003.  Educational Attainmen | Master's degree                                          | int
# B15003_024E  | B15003.  Educational Attainmen | Professional school degree                               | int
# B15003_025E  | B15003.  Educational Attainmen | Doctorate degree                                         | int
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# It comes with a `.geographies()` module

# %%
# geography object - * is wildcard
geo = censusdata.censusgeo(geo = [('state', '*')])
type(geo)
# Out:
# censusdata.censusgeo.censusgeo

# %%
# grab all the states in acs1 of year 2017
censusdata.geographies(within = geo, src='acs1', year=2017)
# Out:
# {'Alabama': censusgeo((('state', '01'),)),
#  'Alaska': censusgeo((('state', '02'),)),
#  'Arizona': censusgeo((('state', '04'),)),
#  'Arkansas': censusgeo((('state', '05'),)),
#  'California': censusgeo((('state', '06'),)),
#  'Colorado': censusgeo((('state', '08'),)),
#  'Connecticut': censusgeo((('state', '09'),)),
#  'Delaware': censusgeo((('state', '10'),)),
#  'District of Columbia': censusgeo((('state', '11'),)),
#  'Florida': censusgeo((('state', '12'),)),
#  'Georgia': censusgeo((('state', '13'),)),
#  'Hawaii': censusgeo((('state', '15'),)),
#  'Idaho': censusgeo((('state', '16'),)),
#  'Illinois': censusgeo((('state', '17'),)),
#  'Indiana': censusgeo((('state', '18'),)),
#  'Iowa': censusgeo((('state', '19'),)),
#  'Kansas': censusgeo((('state', '20'),)),
#  'Kentucky': censusgeo((('state', '21'),)),
#  'Louisiana': censusgeo((('state', '22'),)),
#  'Maine': censusgeo((('state', '23'),)),
#  'Maryland': censusgeo((('state', '24'),)),
#  'Massachusetts': censusgeo((('state', '25'),)),
#  'Michigan': censusgeo((('state', '26'),)),
#  'Minnesota': censusgeo((('state', '27'),)),
#  'Mississippi': censusgeo((('state', '28'),)),
#  'Missouri': censusgeo((('state', '29'),)),
#  'Montana': censusgeo((('state', '30'),)),
#  'Nebraska': censusgeo((('state', '31'),)),
#  'Nevada': censusgeo((('state', '32'),)),
#  'New Hampshire': censusgeo((('state', '33'),)),
#  'New Jersey': censusgeo((('state', '34'),)),
#  'New Mexico': censusgeo((('state', '35'),)),
#  'New York': censusgeo((('state', '36'),)),
#  'North Carolina': censusgeo((('state', '37'),)),
#  'North Dakota': censusgeo((('state', '38'),)),
#  'Ohio': censusgeo((('state', '39'),)),
#  'Oklahoma': censusgeo((('state', '40'),)),
#  'Oregon': censusgeo((('state', '41'),)),
#  'Pennsylvania': censusgeo((('state', '42'),)),
#  'Rhode Island': censusgeo((('state', '44'),)),
#  'South Carolina': censusgeo((('state', '45'),)),
#  'South Dakota': censusgeo((('state', '46'),)),
#  'Tennessee': censusgeo((('state', '47'),)),
#  'Texas': censusgeo((('state', '48'),)),
#  'Utah': censusgeo((('state', '49'),)),
#  'Vermont': censusgeo((('state', '50'),)),
#  'Virginia': censusgeo((('state', '51'),)),
#  'Washington': censusgeo((('state', '53'),)),
#  'West Virginia': censusgeo((('state', '54'),)),
#  'Wisconsin': censusgeo((('state', '55'),)),
#  'Wyoming': censusgeo((('state', '56'),)),
#  'Puerto Rico': censusgeo((('state', '72'),))}

# %%
# grab all counties in state X from acs1 in 2017
geo = censusdata.censusgeo([("state", "06"), ("county", "*")])
censusdata.geographies(within=geo, src = 'acs1', year = 2017)
# Out:
# {'Alameda County, California': censusgeo((('state', '06'), ('county', '001'))),
#  'Butte County, California': censusgeo((('state', '06'), ('county', '007'))),
#  'Contra Costa County, California': censusgeo((('state', '06'), ('county', '013'))),
#  'El Dorado County, California': censusgeo((('state', '06'), ('county', '017'))),
#  'Fresno County, California': censusgeo((('state', '06'), ('county', '019'))),
#  'Humboldt County, California': censusgeo((('state', '06'), ('county', '023'))),
#  'Imperial County, California': censusgeo((('state', '06'), ('county', '025'))),
#  'Kern County, California': censusgeo((('state', '06'), ('county', '029'))),
#  'Kings County, California': censusgeo((('state', '06'), ('county', '031'))),
#  'Lake County, California': censusgeo((('state', '06'), ('county', '033'))),
#  'Los Angeles County, California': censusgeo((('state', '06'), ('county', '037'))),
#  'Madera County, California': censusgeo((('state', '06'), ('county', '039'))),
#  'Marin County, California': censusgeo((('state', '06'), ('county', '041'))),
#  'Mendocino County, California': censusgeo((('state', '06'), ('county', '045'))),
#  'Merced County, California': censusgeo((('state', '06'), ('county', '047'))),
#  'Monterey County, California': censusgeo((('state', '06'), ('county', '053'))),
#  'Napa County, California': censusgeo((('state', '06'), ('county', '055'))),
#  'Nevada County, California': censusgeo((('state', '06'), ('county', '057'))),
#  'Orange County, California': censusgeo((('state', '06'), ('county', '059'))),
#  'Placer County, California': censusgeo((('state', '06'), ('county', '061'))),
#  'Riverside County, California': censusgeo((('state', '06'), ('county', '065'))),
#  'Sacramento County, California': censusgeo((('state', '06'), ('county', '067'))),
#  'San Bernardino County, California': censusgeo((('state', '06'), ('county', '071'))),
#  'San Diego County, California': censusgeo((('state', '06'), ('county', '073'))),
#  'San Francisco County, California': censusgeo((('state', '06'), ('county', '075'))),
#  'San Joaquin County, California': censusgeo((('state', '06'), ('county', '077'))),
#  'San Luis Obispo County, California': censusgeo((('state', '06'), ('county', '079'))),
#  'San Mateo County, California': censusgeo((('state', '06'), ('county', '081'))),
#  'Santa Barbara County, California': censusgeo((('state', '06'), ('county', '083'))),
#  'Santa Clara County, California': censusgeo((('state', '06'), ('county', '085'))),
#  'Santa Cruz County, California': censusgeo((('state', '06'), ('county', '087'))),
#  'Shasta County, California': censusgeo((('state', '06'), ('county', '089'))),
#  'Solano County, California': censusgeo((('state', '06'), ('county', '095'))),
#  'Sonoma County, California': censusgeo((('state', '06'), ('county', '097'))),
#  'Stanislaus County, California': censusgeo((('state', '06'), ('county', '099'))),
#  'Sutter County, California': censusgeo((('state', '06'), ('county', '101'))),
#  'Tulare County, California': censusgeo((('state', '06'), ('county', '107'))),
#  'Ventura County, California': censusgeo((('state', '06'), ('county', '111'))),
#  'Yolo County, California': censusgeo((('state', '06'), ('county', '113'))),
#  'Yuba County, California': censusgeo((('state', '06'), ('county', '115')))}

# %% [markdown]
# # Exercise

# %% [markdown]
# education variables

# %%
 ('B28011_002E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!With an Internet subscription'),
 ('B28011_003E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!With an Internet subscription!!Dial-up alone'),
 ('B28011_004E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!With an Internet subscription!!Broadband such as cable, fiber optic, or DSL'),
 ('B28011_005E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!With an Internet subscription!!Satellite Internet service'),
 ('B28011_006E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!With an Internet subscription!!Other service'),
 ('B28011_007E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!Internet access without a subscription'),
 ('B28011_008E',
  'INTERNET SUBSCRIPTIONS IN HOUSEHOLD',
  'Estimate!!Total!!No Internet access')

# %%
my_vars = ["B28011_002E",
           "B28011_003E",
           "B28011_004E",
           "B28011_005E",
           "B28011_006E",
           "B28011_007E",
           "B28011_008E",
          ]

# %% [markdown]
# Grab your geographies

# %%
geography_of_interest = [("state", "06")]
my_geo = censusdata.censusgeo(geo = geography_of_interest)

# %%
data = censusdata.download(src = 'acs1', year = 2017, geo = my_geo, var = my_vars)

# %%
data.head()
# Out:
#                                           B28011_002E  B28011_003E  \
# California: Summary level: 040, state:06     11432470        31868
#
#                                           B28011_004E  B28011_005E  \
# California: Summary level: 040, state:06      9672461      1018655
#
#                                           B28011_006E  B28011_007E  \
# California: Summary level: 040, state:06       115040       293167
#
#                                           B28011_008E
# California: Summary level: 040, state:06      1279460

# %%
rename_vars = {
    "B28011_002E": 'internet access',
    "B28011_003E": 'dialup',
    "B28011_004E": 'broadband',
    "B28011_005E": 'satellite',
    "B28011_006E": 'other',
    "B28011_007E": 'no subscription',
    "B28011_008E": 'no internet access',
}

# %%
# need to do this because rename returns dataframe
data = data.rename(mapper = rename_vars, axis = 1)

# %%
data.head()
# Out:
#                                           internet access  dialup  broadband  \
# California: Summary level: 040, state:06         11432470   31868    9672461
#
#                                           satellite   other  no subscription  \
# California: Summary level: 040, state:06    1018655  115040           293167
#
#                                           no internet access
# California: Summary level: 040, state:06             1279460

# %%
data['broadband'] / (data['internet access'] + data['no internet access'])
# Out:
# California: Summary level: 040, state:06    0.760896
# dtype: float64

# %% [markdown]
# # Download data

# %%
('B28009I_003E',
  'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
  'Estimate!!Total!!Has a computer!!With dial-up Internet subscription alone'),
 ('B28009I_004E',
  'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
  'Estimate!!Total!!Has a computer!!With a broadband Internet subscription'),
 ('B28009I_005E',
  'PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (HISPANIC OR LATINO)',
  'Estimate!!Total!!Has a computer!!Without an Internet subscription'),

# %%
my_vars = ["B28009I_003E", "B28009I_004E", "B28009I_005E"]

# %% [markdown]
# Grab your geographies

# %%
geography_of_interest = [("state", "06")]
my_geo = censusdata.censusgeo(geo = geography_of_interest)

# %%
data = censusdata.download(src = 'acs1', year = 2017, geo = my_geo, var = my_vars)

# %%
data.head()
# Out:
#                                           B28009I_003E  B28009I_004E  \
# California: Summary level: 040, state:06         15944      13245600
#
#                                           B28009I_005E
# California: Summary level: 040, state:06       1244285

# %%
rename_vars = {
    "B28009I_003E": "dialup", 
    "B28009I_004E": "broadband", 
    "B28009I_005E": "no internet",
}

# %%
# need to do this because rename returns dataframe
data = data.rename(mapper = rename_vars, axis = 1)

# %%
data.head()
# Out:
#                                           dialup  broadband  no internet
# California: Summary level: 040, state:06   15944   13245600      1244285

# %% [markdown]
# # Download data

# %%
censusdata.download?
# Out:
# Signature:
# censusdata.download(
#     src,
#     year,
#     geo,
#     var,
#     key=None,
#     tabletype='detail',
#     endpt='',
# )
# Docstring:
# Download data from Census API.
#
# Args:
#         src (str): Census data source: 'acs1' for ACS 1-year estimates, 'acs5' for ACS 5-year estimates, 'acs3' for
#                 ACS 3-year estimates, 'acsse' for ACS 1-year supplemental estimates, 'sf1' for SF1 data.
#         year (int): Year of data.
#         geo (censusgeo): Geographies for which to download data.
#         var (list of str): Census variables to download.
#         key (str, optional): Census API key.
#         tabletype (str, optional): Type of table from which variables are drawn (only applicable to ACS data). Options are 'detail' (detail tables),
#                 'subject' (subject tables), 'profile' (data profile tables), 'cprofile' (comparison profile tables).
#         endpt (str, optional): Allows override of whether old or new API endpoint is used. Specify
#                 'old' for old, 'new' for new, '' to use default. This option generally shouldn't
#                 need to be specified but can be helpful if download problems are encountered.
#
# Returns:
#         pandas.DataFrame: Data frame with columns corresponding to designated variables, and row index of censusgeo objects representing Census geographies.
#
# Raises:
#         ValueError: If unknown tabletype is specified.
#
# Examples::
#
#         # Download ACS 2011-2015 5-year estimates for Oakland city, California on population size, median age, and median household income.
#         censusdata.download('acs5', 2015, censusdata.censusgeo([('state', '06'), ('place', '53000')]), ['B01001_001E', 'B01002_001E', 'B19013_001E'])
# File:      c:\users\sanchez\appdata\local\continuum\anaconda3\envs\pycon2019\lib\site-packages\censusdata\download.py
# Type:      function

# %%
data = censusdata.download(src = 'acs1', year = 2017, geo = my_geo, var = my_vars)

# %%
data.head()
# Out:
#                                           B28009I_003E  B28009I_004E  \
# California: Summary level: 040, state:06         15944      13245600
#
#                                           B28009I_005E
# California: Summary level: 040, state:06       1244285

# %%
rename_vars = {
    "B28009I_003E": "dialup", 
    "B28009I_004E": "broadband", 
    "B28009I_005E": "no internet",
}

# %%
# need to do this because rename returns dataframe
data = data.rename(mapper = rename_vars, axis = 1)

# %%
data.head()
# Out:
#                                           dialup  broadband  no internet
# California: Summary level: 040, state:06   15944   13245600      1244285

# %%
data['total'] = data['dialup'] + data['broadband'] + data['no internet']

# %%
data['share of broadband'] = data['broadband'] / data['total']

# %%
data.head()
# Out:
#                                           dialup  broadband  no internet  \
# California: Summary level: 040, state:06   15944   13245600      1244285
#
#                                              total  share of broadband
# California: Summary level: 040, state:06  14505829            0.913123

# %% [markdown]
# # Advanced data prepping
#
# This data kind of works but ideally we would have something like this
#
# | County |    State   | Summary level | State Code | County Code | Bachelors | Masters | Professional degree | Doctorates | Total | share of bachelors+ |
# |:------:|:----------:|:-------------:|:----------:|:-----------:|:---------:|:-------:|:-------------------:|:----------:|:-----:|:-------------------:|
# | Modoc  | California |       050     |     06     |     049     |     859   |   227   |          50         |      0     |  6852 |       0.165791      |
# | Merced | California |       050     |     06     |     047     |   14006   |  5063   |        1337         |   1135     |156562 |       0.137588      |
# | Lake   | California |       050     |     06     |     033     |    4588   |  1678   |         577         |    273     | 56386 |       0.153408      |
# |Mariposa| California |       050     |     06     |     043     |    2017   |   933   |         253         |    132     | 13656 |       0.244215      |
# |  Yuba  | California |       050     |     06     |     115     |    5573   |  1565   |         406         |     84     | 56582 |       0.163754      |

# %% [markdown]
# First step, `.reset_index()`

# %%
# this returns dataframe so we need to assign it back to itself
data = data.reset_index()

# %%
data.head()
# Out:
#                                                index  Bachelors  Masters  \
# 0  Modoc County, California: Summary level: 050, ...        859      227
# 1  Merced County, California: Summary level: 050,...      14006     5063
# 2  Lake County, California: Summary level: 050, s...       4588     1678
# 3  Mariposa County, California: Summary level: 05...       2017      933
# 4  Yuba County, California: Summary level: 050, s...       5573     1565
#
#    Professional degree  Doctorates   Total  share of bachelors+
# 0                   50           0    6852             0.165791
# 1                 1337        1135  156562             0.137588
# 2                  577         273   46386             0.153408
# 3                  253         132   13656             0.244215
# 4                  406          84   46582             0.163754

# %% [markdown]
# `.str` accessor - lets you apply string methods to pandas series - however our index is a `censusgeo` object

# %%
print(data['index'][0])
print(data['index'][0].hierarchy())
# Out:
# Modoc County, California: Summary level: 050, state:06> county:049
# state> county

# %% [markdown]
# Save as string

# %%
data['index_as_string'] = data['index'].astype(str)

# %%
data.head()
# Out:
#                                                index  Bachelors  Masters  \
# 0  Modoc County, California: Summary level: 050, ...        859      227
# 1  Merced County, California: Summary level: 050,...      14006     5063
# 2  Lake County, California: Summary level: 050, s...       4588     1678
# 3  Mariposa County, California: Summary level: 05...       2017      933
# 4  Yuba County, California: Summary level: 050, s...       5573     1565
#
#    Professional degree  Doctorates   Total  share of bachelors+  \
# 0                   50           0    6852             0.165791
# 1                 1337        1135  156562             0.137588
# 2                  577         273   46386             0.153408
# 3                  253         132   13656             0.244215
# 4                  406          84   46582             0.163754
#
#                                      index_as_string
# 0  Modoc County, California: Summary level: 050, ...
# 1  Merced County, California: Summary level: 050,...
# 2  Lake County, California: Summary level: 050, s...
# 3  Mariposa County, California: Summary level: 05...
# 4  Yuba County, California: Summary level: 050, s...

# %%
# .str accessor
data['index_as_string'].str.split(":").str[0]
# Out:
# 0               Modoc County, California
# 1              Merced County, California
# 2                Lake County, California
# 3            Mariposa County, California
# 4                Yuba County, California
# 5        Contra Costa County, California
# 6                Inyo County, California
# 7              Lassen County, California
# 8          Stanislaus County, California
# 9       Santa Barbara County, California
# 10             Sonoma County, California
# 11             Tehama County, California
# 12           Imperial County, California
# 13               Mono County, California
# 14         San Benito County, California
# 15            Alameda County, California
# 16         Sacramento County, California
# 17          El Dorado County, California
# 18               Napa County, California
# 19          San Diego County, California
# 20           Monterey County, California
# 21      San Francisco County, California
# 22             Sierra County, California
# 23             Tulare County, California
# 24               Yolo County, California
# 25           Humboldt County, California
# 26             Nevada County, California
# 27             Alpine County, California
# 28             Madera County, California
# 29          Mendocino County, California
# 30         Santa Cruz County, California
# 31            Trinity County, California
# 32        Los Angeles County, California
# 33          Riverside County, California
# 34     San Bernardino County, California
# 35        Santa Clara County, California
# 36              Marin County, California
# 37             Placer County, California
# 38           Siskiyou County, California
# 39             Shasta County, California
# 40             Solano County, California
# 41          Del Norte County, California
# 42             Colusa County, California
# 43              Glenn County, California
# 44              Butte County, California
# 45              Kings County, California
# 46             Plumas County, California
# 47    San Luis Obispo County, California
# 48             Fresno County, California
# 49               Kern County, California
# 50             Orange County, California
# 51            Ventura County, California
# 52          Calaveras County, California
# 53             Sutter County, California
# 54          San Mateo County, California
# 55           Tuolumne County, California
# 56        San Joaquin County, California
# 57             Amador County, California
# Name: index_as_string, dtype: object

# %% [markdown]
# ### now we know somethings already
# 1. these are all in California so `State` and `State Code` are 'California' and '06' respectively for all of them.
# 2. Summary Level is the same for all: 050
#
# So what we really need is `County` and `County Code`

# %%
# rough way 
data['index_as_string'].str.split("County").str[0]
# Out:
# 0               Modoc
# 1              Merced
# 2                Lake
# 3            Mariposa
# 4                Yuba
# 5        Contra Costa
# 6                Inyo
# 7              Lassen
# 8          Stanislaus
# 9       Santa Barbara
# 10             Sonoma
# 11             Tehama
# 12           Imperial
# 13               Mono
# 14         San Benito
# 15            Alameda
# 16         Sacramento
# 17          El Dorado
# 18               Napa
# 19          San Diego
# 20           Monterey
# 21      San Francisco
# 22             Sierra
# 23             Tulare
# 24               Yolo
# 25           Humboldt
# 26             Nevada
# 27             Alpine
# 28             Madera
# 29          Mendocino
# 30         Santa Cruz
# 31            Trinity
# 32        Los Angeles
# 33          Riverside
# 34     San Bernardino
# 35        Santa Clara
# 36              Marin
# 37             Placer
# 38           Siskiyou
# 39             Shasta
# 40             Solano
# 41          Del Norte
# 42             Colusa
# 43              Glenn
# 44              Butte
# 45              Kings
# 46             Plumas
# 47    San Luis Obispo
# 48             Fresno
# 49               Kern
# 50             Orange
# 51            Ventura
# 52          Calaveras
# 53             Sutter
# 54          San Mateo
# 55           Tuolumne
# 56        San Joaquin
# 57             Amador
# Name: index_as_string, dtype: object

# %%
data['index_as_string'].str.split("county").str[-1].str.replace(":", "")
# Out:
# 0     049
# 1     047
# 2     033
# 3     043
# 4     115
# 5     013
# 6     027
# 7     035
# 8     099
# 9     083
# 10    097
# 11    103
# 12    025
# 13    051
# 14    069
# 15    001
# 16    067
# 17    017
# 18    055
# 19    073
# 20    053
# 21    075
# 22    091
# 23    107
# 24    113
# 25    023
# 26    057
# 27    003
# 28    039
# 29    045
# 30    087
# 31    105
# 32    037
# 33    065
# 34    071
# 35    085
# 36    041
# 37    061
# 38    093
# 39    089
# 40    095
# 41    015
# 42    011
# 43    021
# 44    007
# 45    031
# 46    063
# 47    079
# 48    019
# 49    029
# 50    059
# 51    111
# 52    009
# 53    101
# 54    081
# 55    109
# 56    077
# 57    005
# Name: index_as_string, dtype: object

# %% [markdown]
# Pandas split has `expand` option

# %% [markdown]
# examine first observation

# %%
data['index_as_string'][0]
# Out:
# 'Modoc County, California: Summary level: 050, state:06> county:049'

# %% [markdown]
# The county name is right before "County,"

# %%
# gotta chain .str accessor every time you need to apply a string method to a series
data['index_as_string'].str.split("County,").str[0].str.strip()
# Out:
# 0               Modoc
# 1              Merced
# 2                Lake
# 3            Mariposa
# 4                Yuba
# 5        Contra Costa
# 6                Inyo
# 7              Lassen
# 8          Stanislaus
# 9       Santa Barbara
# 10             Sonoma
# 11             Tehama
# 12           Imperial
# 13               Mono
# 14         San Benito
# 15            Alameda
# 16         Sacramento
# 17          El Dorado
# 18               Napa
# 19          San Diego
# 20           Monterey
# 21      San Francisco
# 22             Sierra
# 23             Tulare
# 24               Yolo
# 25           Humboldt
# 26             Nevada
# 27             Alpine
# 28             Madera
# 29          Mendocino
# 30         Santa Cruz
# 31            Trinity
# 32        Los Angeles
# 33          Riverside
# 34     San Bernardino
# 35        Santa Clara
# 36              Marin
# 37             Placer
# 38           Siskiyou
# 39             Shasta
# 40             Solano
# 41          Del Norte
# 42             Colusa
# 43              Glenn
# 44              Butte
# 45              Kings
# 46             Plumas
# 47    San Luis Obispo
# 48             Fresno
# 49               Kern
# 50             Orange
# 51            Ventura
# 52          Calaveras
# 53             Sutter
# 54          San Mateo
# 55           Tuolumne
# 56        San Joaquin
# 57             Amador
# Name: index_as_string, dtype: object

# %%
# save it as a colum
data['County'] = data['index_as_string'].str.split("County,").str[0].str.strip()

# %%
data.head()
# Out:
#                                                index  Bachelors  Masters  \
# 0  Modoc County, California: Summary level: 050, ...        859      227
# 1  Merced County, California: Summary level: 050,...      14006     5063
# 2  Lake County, California: Summary level: 050, s...       4588     1678
# 3  Mariposa County, California: Summary level: 05...       2017      933
# 4  Yuba County, California: Summary level: 050, s...       5573     1565
#
#    Professional degree  Doctorates   Total  share of bachelors+  \
# 0                   50           0    6852             0.165791
# 1                 1337        1135  156562             0.137588
# 2                  577         273   46386             0.153408
# 3                  253         132   13656             0.244215
# 4                  406          84   46582             0.163754
#
#                                      index_as_string    County
# 0  Modoc County, California: Summary level: 050, ...     Modoc
# 1  Merced County, California: Summary level: 050,...    Merced
# 2  Lake County, California: Summary level: 050, s...      Lake
# 3  Mariposa County, California: Summary level: 05...  Mariposa
# 4  Yuba County, California: Summary level: 050, s...      Yuba

# %%
# same with county code
data['index_as_string'].str.split("county:").str[-1].str.strip()
# Out:
# 0     049
# 1     047
# 2     033
# 3     043
# 4     115
# 5     013
# 6     027
# 7     035
# 8     099
# 9     083
# 10    097
# 11    103
# 12    025
# 13    051
# 14    069
# 15    001
# 16    067
# 17    017
# 18    055
# 19    073
# 20    053
# 21    075
# 22    091
# 23    107
# 24    113
# 25    023
# 26    057
# 27    003
# 28    039
# 29    045
# 30    087
# 31    105
# 32    037
# 33    065
# 34    071
# 35    085
# 36    041
# 37    061
# 38    093
# 39    089
# 40    095
# 41    015
# 42    011
# 43    021
# 44    007
# 45    031
# 46    063
# 47    079
# 48    019
# 49    029
# 50    059
# 51    111
# 52    009
# 53    101
# 54    081
# 55    109
# 56    077
# 57    005
# Name: index_as_string, dtype: object

# %%
data['County Code'] = data['index_as_string'].str.split("county:").str[-1].str.strip()

# %%
data.head()
# Out:
#                                                index  Bachelors  Masters  \
# 0  Modoc County, California: Summary level: 050, ...        859      227
# 1  Merced County, California: Summary level: 050,...      14006     5063
# 2  Lake County, California: Summary level: 050, s...       4588     1678
# 3  Mariposa County, California: Summary level: 05...       2017      933
# 4  Yuba County, California: Summary level: 050, s...       5573     1565
#
#    Professional degree  Doctorates   Total  share of bachelors+  \
# 0                   50           0    6852             0.165791
# 1                 1337        1135  156562             0.137588
# 2                  577         273   46386             0.153408
# 3                  253         132   13656             0.244215
# 4                  406          84   46582             0.163754
#
#                                      index_as_string    County County Code
# 0  Modoc County, California: Summary level: 050, ...     Modoc         049
# 1  Merced County, California: Summary level: 050,...    Merced         047
# 2  Lake County, California: Summary level: 050, s...      Lake         033
# 3  Mariposa County, California: Summary level: 05...  Mariposa         043
# 4  Yuba County, California: Summary level: 050, s...      Yuba         115

# %%
# the rest of the columns are easy to create
data['State'] = 'California'
data['State Code'] = '06'
data['Summary Level'] = '050'

# %% [markdown]
# Pandas creates a series with all values = to the string you pass

# %%
data.head()
# Out:
#                                                index  Bachelors  Masters  \
# 0  Modoc County, California: Summary level: 050, ...        859      227
# 1  Merced County, California: Summary level: 050,...      14006     5063
# 2  Lake County, California: Summary level: 050, s...       4588     1678
# 3  Mariposa County, California: Summary level: 05...       2017      933
# 4  Yuba County, California: Summary level: 050, s...       5573     1565
#
#    Professional degree  Doctorates   Total  share of bachelors+  \
# 0                   50           0    6852             0.165791
# 1                 1337        1135  156562             0.137588
# 2                  577         273   46386             0.153408
# 3                  253         132   13656             0.244215
# 4                  406          84   46582             0.163754
#
#                                      index_as_string    County County Code  \
# 0  Modoc County, California: Summary level: 050, ...     Modoc         049
# 1  Merced County, California: Summary level: 050,...    Merced         047
# 2  Lake County, California: Summary level: 050, s...      Lake         033
# 3  Mariposa County, California: Summary level: 05...  Mariposa         043
# 4  Yuba County, California: Summary level: 050, s...      Yuba         115
#
#         State State Code Summary Level
# 0  California         06           050
# 1  California         06           050
# 2  California         06           050
# 3  California         06           050
# 4  California         06           050

# %%
# select a group of columns
columns_im_interested_in = ['State', 'State Code', 'County', 'County Code', 'Summary Level', 'share of bachelors+']
data[columns_im_interested_in].head()
# Out:
#         State State Code    County County Code Summary Level  \
# 0  California         06     Modoc         049           050
# 1  California         06    Merced         047           050
# 2  California         06      Lake         033           050
# 3  California         06  Mariposa         043           050
# 4  California         06      Yuba         115           050
#
#    share of bachelors+
# 0             0.165791
# 1             0.137588
# 2             0.153408
# 3             0.244215
# 4             0.163754

# %% [markdown]
# save that to a clean dataframe

# %%
clean_data = data[columns_im_interested_in]

# %% [markdown]
# # .copy() vs subset

# %% [markdown]
# Right now, clean_data is "pointing" (is a `view`) to a subset of data so any changes you do to clean_data aren't _guaranteed_ to work. sometimes they do sometimes they don't. So you should create a .copy() of the data if you plan on modifying it after.

# %%
clean_data['State'] = 'CA'
# Out:
# C:\Users\sanchez\AppData\Local\Continuum\anaconda3\envs\pycon2019\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
clean_data = data[columns_im_interested_in].copy()

# %%
clean_data['State'] = 'CA'

# %% [markdown]
# No warning

# %%
clean_data.head()
# Out:
#   State State Code    County County Code Summary Level  share of bachelors+
# 0    CA         06     Modoc         049           050             0.165791
# 1    CA         06    Merced         047           050             0.137588
# 2    CA         06      Lake         033           050             0.153408
# 3    CA         06  Mariposa         043           050             0.244215
# 4    CA         06      Yuba         115           050             0.163754

# %% [markdown]
# Save data

# %%
clean_data.to_csv("../data/interim/censusdata_example.csv", index = False,)
